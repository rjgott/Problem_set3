# %% [markdown]
# Python Scripts for PROBLEM SET 3 - Python Scripts (Python 3.10.7 in VS-Code)
# Riley J. Gott
# October 21, 2022

# %%
 #Function to open data file for water level problem set    

def open_file():
    
    try:
        my_fhand = open('/bsc4452/share/Class_Files/data/CO-OPS__8729108__wl.csv')
        print("Data file opened for reading")
    except:
        print("WARNING - Could not open file")
    return my_fhand

open_file()

# %%
###Problem 1 - report the highest water level and the date and time it was observed.

open_file()
my_fhand = open('/bsc4452/share/Class_Files/data/CO-OPS__8729108__wl.csv')
max_water_level = 0
Date_Time_max_water_level = ''
my_fhand.readline()

count = 0
for line in my_fhand:
    line = line.strip()
    columns = line.split(sep=',')
    print(columns[1], columns[0])
    Date_Time = columns[0]
    
    try:
        water_level = float(columns[1])
    except:
        print(f"No water level data for this {Date_Time}")
    
    if water_level > max_water_level: #Find and report higher water levels found 
        print("New max water level found!")
        max_water_level = water_level
        Date_Time_max_water_level = Date_Time

print('The maximum water level was:', max_water_level, 'at', Date_Time_max_water_level) #Print the highest water level in the data set.
# Out:
# Data file opened for reading
# 2.421 2018-10-09 00:00
# New max water level found!
# 2.454 2018-10-09 00:06
# New max water level found!
# 2.461 2018-10-09 00:12
# New max water level found!
# 2.444 2018-10-09 00:18
# 2.431 2018-10-09 00:24
# 2.421 2018-10-09 00:30
# 2.411 2018-10-09 00:36
# 2.375 2018-10-09 00:42
# 2.388 2018-10-09 00:48
# 2.365 2018-10-09 00:54
# 2.365 2018-10-09 01:00
# 2.346 2018-10-09 01:06
# 2.352 2018-10-09 01:12
# 2.349 2018-10-09 01:18
# 2.388 2018-10-09 01:24
# 2.382 2018-10-09 01:30
# 2.448 2018-10-09 01:36
# 2.431 2018-10-09 01:42
# 2.467 2018-10-09 01:48
# New max water level found!
# 2.487 2018-10-09 01:54
# New max water level found!
# 2.536 2018-10-09 02:00
# New max water level found!
# 2.559 2018-10-09 02:06
# New max water level found!
# 2.592 2018-10-09 02:12
# New max water level found!
# 2.598 2018-10-09 02:18
# New max water level found!
# 2.602 2018-10-09 02:24
# New max water level found!
# 2.608 2018-10-09 02:30
# New max water level found!
# ...

# %%
###Problem 2 - find lowest, highest, and average water level
    #lowest code first
    #highest code second
    #average code third
    
open_file()
my_fhand = open('/bsc4452/share/Class_Files/data/CO-OPS__8729108__wl.csv')
my_fhand.readline()

low_water_level = 6.647 #low water level needs to be higher than the lowest reported water level in dataset so set this variable to the highest reported water level since everything else reported will be lower.
Date_Time_low_water_level = ''

max_water_level = 0
Date_Time_max_water_level = ''

count = 0
for line in my_fhand:
    count = count + 1
    line = line.strip()
    columns = line.split(sep=',')
    print(columns[1], columns[0])
    Date_Time = columns[0]
    
    try:
        water_level = float(columns[1])
    except:
        print(f"WARNING - No water level data for this {Date_Time}")
    
    if water_level < low_water_level: #Find and report lower water levels
        print("New low water level found!")
        low_water_level = water_level
        Date_Time_low_water_level = Date_Time

    if water_level > max_water_level: #Find and report lower water levels
        print("New max water level found!")
        max_water_level = water_level
        Date_Time_max_water_level = Date_Time

    

print('The lowest water level was:', low_water_level, 'at', Date_Time_low_water_level) #Report the lowest water level in the data set.

print('The maximum water level was:', max_water_level, 'at', Date_Time_max_water_level) #Report the highest water level in the data set.

print('The average water level was:', avg_water_level) #no average value calculated yet... attempted to figure out code for averaging floating point columns in below code box - unsuccessful so far
# Out:
# Data file opened for reading
# 2.421 2018-10-09 00:00
# New low water level found!
# New max water level found!
# 2.454 2018-10-09 00:06
# New max water level found!
# 2.461 2018-10-09 00:12
# New max water level found!
# 2.444 2018-10-09 00:18
# 2.431 2018-10-09 00:24
# 2.421 2018-10-09 00:30
# 2.411 2018-10-09 00:36
# New low water level found!
# 2.375 2018-10-09 00:42
# New low water level found!
# 2.388 2018-10-09 00:48
# 2.365 2018-10-09 00:54
# New low water level found!
# 2.365 2018-10-09 01:00
# 2.346 2018-10-09 01:06
# New low water level found!
# 2.352 2018-10-09 01:12
# 2.349 2018-10-09 01:18
# 2.388 2018-10-09 01:24
# 2.382 2018-10-09 01:30
# 2.448 2018-10-09 01:36
# 2.431 2018-10-09 01:42
# 2.467 2018-10-09 01:48
# New max water level found!
# 2.487 2018-10-09 01:54
# New max water level found!
# 2.536 2018-10-09 02:00
# New max water level found!
# 2.559 2018-10-09 02:06
# New max water level found!
# 2.592 2018-10-09 02:12
# New max water level found!
# ...

# %%
### Attempt to calculate average of floating point values... No success... various error messages on all methods attempted

open_file()
my_fhand = open('/bsc4452/share/Class_Files/data/CO-OPS__8729108__wl.csv')
my_fhand.readline()

from statistics import mean
import math

for line in my_fhand:
    count = count + 1
    line = line.strip()
    columns = line.split(sep=',')
    print(columns[1])
    
    try:
        water_level = float(columns[1])
        

    except:
        print('WARNING - error making water_level')


print('The average water level was:', avg_water_level)
# Out:
# Data file opened for reading
# 2.421
# WARNING - error making water_level
# 2.454
# WARNING - error making water_level
# 2.461
# WARNING - error making water_level
# 2.444
# WARNING - error making water_level
# 2.431
# WARNING - error making water_level
# 2.421
# WARNING - error making water_level
# 2.411
# WARNING - error making water_level
# 2.375
# WARNING - error making water_level
# 2.388
# WARNING - error making water_level
# 2.365
# WARNING - error making water_level
# 2.365
# WARNING - error making water_level
# 2.346
# WARNING - error making water_level
# 2.352
# WARNING - error making water_level
# 2.349
# WARNING - error making water_level
# 2.388
# WARNING - error making water_level
# 2.382
# WARNING - error making water_level
# 2.448
# WARNING - error making water_level
# 2.431
# WARNING - error making water_level
# 2.467
# WARNING - error making water_level
# 2.487
# WARNING - error making water_level
# 2.536
# WARNING - error making water_level
# 2.559
# ...

# %%
###Problem 3 

open_file()
my_fhand = open('/bsc4452/share/Class_Files/data/CO-OPS__8729108__wl.csv')
my_fhand.readline()
# Out:
# Data file opened for reading
# 'Date Time, Water Level, Sigma, O, F, R, L, Quality \n'

# %%
###Problem 4 - Print warnings for live water readings of water level if any of the below conditions occur
    #Water level increases 0.25 or more since previous reading 
    #Water leve is over 5.0
    #No water level reading

open_file()
my_fhand = open('/bsc4452/share/Class_Files/data/CO-OPS__8729108__wl.csv')
my_fhand.readline()
water_level = 2.421 

for line in my_fhand:
    line = line.strip()
    columns = line.split(sep=',')
    print(columns[1], columns[0])
    water_level_increase = water_level + 0.249
    Date_Time = columns[0]
    
    try: #Convert entries to floating point values
        water_level = float(columns[1])

    except: #Print warning if water level reading not taken
        print(f"WARNING - No water level reading at {Date_Time}")

    if water_level > water_level_increase: #Print warning that water level increased 0.25 or more since previous warning
        print(f"WARNING - Water level increased 0.25 or more")
        water_level_increase = water_level + 0.249

    if water_level > 5.0: #Print warning if water level is over 5.0
        print("WARNING - Water level is over 5.0")
# Out:
# Data file opened for reading
# 2.421 2018-10-09 00:00
# 2.454 2018-10-09 00:06
# 2.461 2018-10-09 00:12
# 2.444 2018-10-09 00:18
# 2.431 2018-10-09 00:24
# 2.421 2018-10-09 00:30
# 2.411 2018-10-09 00:36
# 2.375 2018-10-09 00:42
# 2.388 2018-10-09 00:48
# 2.365 2018-10-09 00:54
# 2.365 2018-10-09 01:00
# 2.346 2018-10-09 01:06
# 2.352 2018-10-09 01:12
# 2.349 2018-10-09 01:18
# 2.388 2018-10-09 01:24
# 2.382 2018-10-09 01:30
# 2.448 2018-10-09 01:36
# 2.431 2018-10-09 01:42
# 2.467 2018-10-09 01:48
# 2.487 2018-10-09 01:54
# 2.536 2018-10-09 02:00
# 2.559 2018-10-09 02:06
# 2.592 2018-10-09 02:12
# 2.598 2018-10-09 02:18
# 2.602 2018-10-09 02:24
# 2.608 2018-10-09 02:30
# 2.608 2018-10-09 02:36
# 2.618 2018-10-09 02:42
# 2.631 2018-10-09 02:48
# 2.612 2018-10-09 02:54
# 2.605 2018-10-09 03:00
# 2.602 2018-10-09 03:06
# 2.585 2018-10-09 03:12
# 2.598 2018-10-09 03:18
# 2.612 2018-10-09 03:24
# 2.595 2018-10-09 03:30
# 2.602 2018-10-09 03:36
# 2.608 2018-10-09 03:42
# ...
